# %%
import fitz

# %%
pdf_document = fitz.open("test2.pdf")

# %%
page = pdf_document.load_page(0)

# %%
toc = pdf_document.get_toc()

# %%
blocks = page.get_text("dict")["blocks"]

# %%
blocks
# Out:
# [{'number': 0,
#   'type': 0,
#   'bbox': (56.79999923706055,
#    56.6898307800293,
#    538.0111694335938,
#    191.06484985351562),
#   'lines': [{'spans': [{'size': 9.600000381469727,
#       'flags': 4,
#       'font': 'DejaVuSans',
#       'color': 13751771,
#       'ascender': 0.92822265625,
#       'descender': -0.23583984375,
#       'text': 'Diego Maradona faced various legal troubles throughout his life, but he never served a long-term',
#       'origin': (56.79999923706055, 65.60076904296875),
#       'bbox': (56.79999923706055,
#        56.6898307800293,
#        537.6848754882812,
#        67.86483001708984)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (56.79999923706055,
#      56.6898307800293,
#      537.6848754882812,
#      67.86483001708984)},
#    {'spans': [{'size': 9.600000381469727,
#       'flags': 4,
#       'font': 'DejaVuSans',
#       'color': 13751771,
#       'ascender': 0.92822265625,
#       'descender': -0.23583984375,
# ...
